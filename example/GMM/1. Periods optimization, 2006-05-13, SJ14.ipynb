# %% [markdown]
# # GMM - hpo, 2006-05-13, SJ14

# %%
from pathlib import Path
import os

os.chdir(Path(os.getcwd()).parent)

# %%
from AnomalyCableDetection.load import Loader, Preprocessor
from AnomalyCableDetection.stl import CableSTL, CrossCorrelation, AdjacencyType
from AnomalyCableDetection.gmm import *
from AnomalyCableDetection.plot import *

# %%
from sklearn import mixture
from os.path import join
from pathlib import Path

import matplotlib.dates as mdates
import matplotlib.pylab as plt
import seaborn as sns
import pandas as pd
import numpy as np
import glob
import os
import re

# %% [markdown]
# ### Load pre1 dataset

# %%
gmm = CableGMM(sigma_period=210)
cable_dict = gmm.cable_dict
date_list = gmm.date_list
scatter_dict = gmm.scatter_dict

# %% [markdown]
# ### Tension ratio example

# %% [markdown]
# `2006-05-13`, cable `SJ14` pair

# %%
date = date_list[0]
cable_list = get_dup_cable_numbers(cable_dict[date])
cable_number = cable_list[-1]

# %%
period = 30
sigma_list = gmm.get_sigma_list(date, cable_number)
gmm.plot_sigma_list(date, cable_number, sigma_list, period=period)

# %%
model, gmm_x, gmm_y_sum = gmm.get_gmm_model(date, cable_number, period=period)
gmm.plot_gmm(date, cable_number, gmm_x, gmm_y_sum, period=period)

# %%
period = 60
sigma_list = gmm.get_sigma_list(date, cable_number)
gmm.plot_sigma_list(date, cable_number, sigma_list, period=period)

# %%
model, gmm_x, gmm_y_sum = gmm.get_gmm_model(date, cable_number, period=period)
gmm.plot_gmm(date, cable_number, gmm_x, gmm_y_sum, period=period)

# %%
period = 90
sigma_list = gmm.get_sigma_list(date, cable_number)
gmm.plot_sigma_list(date, cable_number, sigma_list, period=period)

# %%
model, gmm_x, gmm_y_sum = gmm.get_gmm_model(date, cable_number, period=period)
gmm.plot_gmm(date, cable_number, gmm_x, gmm_y_sum, period=period)

# %%
period = 120
sigma_list = gmm.get_sigma_list(date, cable_number)
gmm.plot_sigma_list(date, cable_number, sigma_list, period=period)

# %%
model, gmm_x, gmm_y_sum = gmm.get_gmm_model(date, cable_number, period=period)
gmm.plot_gmm(date, cable_number, gmm_x, gmm_y_sum, period=period)

# %% [markdown]
# period = 150
# sigma_list = gmm.get_sigma_list(date, cable_number, period=period)
# gmm.plot_sigma_list(date, cable_number, sigma_list, period=period)

# %% [markdown]
# model, gmm_x, gmm_y_sum = gmm.get_gmm_model(date, cable_number, period=period)
# gmm.plot_gmm(date, cable_number, gmm_x, gmm_y_sum, period=period)

# %% [markdown]
# period = 180
# sigma_list = gmm.get_sigma_list(date, cable_number, period=period)
# gmm.plot_sigma_list(date, cable_number, sigma_list, period=period)

# %% [markdown]
# model, gmm_x, gmm_y_sum = gmm.get_gmm_model(date, cable_number, period=period)
# gmm.plot_gmm(date, cable_number, gmm_x, gmm_y_sum, period=period)

# %% [markdown]
# period = 210
# sigma_list = gmm.get_sigma_list(date, cable_number, period=period)
# gmm.plot_sigma_list(date, cable_number, sigma_list, period=period)

# %% [markdown]
# model, gmm_x, gmm_y_sum = gmm.get_gmm_model(date, cable_number, period=period)
# gmm.plot_gmm(date, cable_number, gmm_x, gmm_y_sum, period=period)
